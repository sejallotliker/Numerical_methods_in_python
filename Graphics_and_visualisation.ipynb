# %% [markdown]
# <a href="https://colab.research.google.com/github/sejallotliker/Numerical_methods_in_python/blob/main/Graphics_and_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Graphs
import matplotlib.pyplot as plt
y = [1.0, 2.4, 1.7, 0.3, 0.6, 1.8]
plt.plot(y)
plt.show()

# %%
import numpy as np
x = np.arange(0, 31.4, 0.005)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
#Scatter plots
from numpy import loadtxt
data = loadtxt("/content/drive/MyDrive/JNCASR/Masters/Sem-2/computational Methods/my_practice_for_compri/Graphics and visualization/stars.txt", float)
x = data[:, 0]
y = data[:, 1]
plt.scatter(x, y)
plt.xlabel("Magnitude")
plt.ylabel("Temperature")
plt.show()

# %%
#Density plots
data = loadtxt("/content/drive/MyDrive/JNCASR/Masters/Sem-2/computational Methods/my_practice_for_compri/Graphics and visualization/circular.txt")
plt.imshow(data, origin='lower')
plt.show()

# %%
plt.imshow(data, origin='lower')
plt.gray()
plt.show()

# %%
#Other colour schemes
# 1. jet : Default heat map color scheme
# 2. gray : Gray scale running from black to white
# 3. hot : balck-red-yellow-white
# 4. spectral: all 7 colours
# 5. bone : gray scale with a hint of blue
# 6. hsv : rainbow scheme that starts and ends with red

# %%
#Wave interference
from math import sqrt, sin, pi
from numpy import empty
from pylab import imshow, gray, show

wavelength = 5.0
k = 2*pi/ wavelength
xi0 = 1.0
seperation = 20
side = 100
points = 500
spacing = side/points

#Calculate the posistions of the centres of the circle
x1 = side/2 + seperation/2
y1 = side/2
x2 = side/2 -seperation/2
y2 = side/2

#Make an array to store the heights
xi = empty([points, points], float)

#Calculate the values in the array
for i in range(points):
  y = spacing*i
  for j in range(points):
    x = spacing*j
    r1 = sqrt((x-x1)**2+(y-y1)**2)
    r2 = sqrt((x-x2)**2+(y-y2)**2)
    xi[i, j] = xi0*sin(k*r1)+ xi0*sin(k*r2)

#To make the plot
imshow(xi, origin='lower', extent=[0, side, 0, side])
gray()
show()

# %%
#STM image
#Density plots
data = loadtxt("/content/drive/MyDrive/JNCASR/Masters/Sem-2/computational Methods/my_practice_for_compri/Graphics and visualization/stm.txt")
plt.imshow(data)
plt.show()
